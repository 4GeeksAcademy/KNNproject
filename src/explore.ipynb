# %% [markdown]
# # Explore here

# %% [markdown]
# First, let's load the dataframes

# %%
import pandas as pd

dfmovies = pd.read_csv('/workspaces/KNNproject/data/raw/movies.csv')
dfmovies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import pandas as pd

dfcredits = pd.read_csv('/workspaces/KNNproject/data/raw/credits.csv')
dfcredits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %% [markdown]
# Let's now create the SQL databases

# %%
import sqlite3

connec = sqlite3.connect("../data/moviesDB.db")

MOVIES = dfmovies.to_sql("Movies", connec, if_exists = "replace", index = False)
CREDITS = dfcredits.to_sql("Credits", connec, if_exists = "replace", index = False)

# %%
query = '''SELECT *
FROM Movies
JOIN Credits ON Movies.original_title = Credits.title;
'''
evereything = pd.read_sql_query(query, connec)
evereything
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4542     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4543       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4544          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4545          0                                                 []
# 4546          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# Now let's eliminate the columns we don't want.

# %%
cols = ['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew']
df = evereything[cols]
df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4542      9367                               El Mariachi
# 4543     72766                                 Newlyweds
# 4544    231617                 Signed, Sealed, Delivered
# 4545    126186                          Shanghai Calling
# 4546     25975                         My Date with Drew
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# ...

# %% [markdown]
# Let's delete the repeated column

# %%
df = df.loc[:, ~df.columns.duplicated()]
df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4542      9367                               El Mariachi
# 4543     72766                                 Newlyweds
# 4544    231617                 Signed, Sealed, Delivered
# 4545    126186                          Shanghai Calling
# 4546     25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# ...

# %% [markdown]
# Let's now filter the jsons.

# %%
import json
def JSON(json_str, default_value = None):
    try:
        return json.loads(json_str)
    except (TypeError, json.JSONDecodeError):
        return default_value

# %%
df['genres'] = df['genres'].apply(lambda x: [item['name'] for item in json.loads(x)] if pd.notna(x) else None)

df['keywords'] = df['keywords'].apply(lambda x: [item['name'] for item in json.loads(x)] if pd.notna(x) else None)

df['cast'] = df['cast'].apply(lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else None)

df['crew'] = df['crew'].apply(lambda x: " ".join([crew_member['name'] for crew_member in JSON(x) if crew_member['job'] == 'Director']))

df['overview'] = df['overview'].apply(lambda x: [x])
# Out:
# /tmp/ipykernel_20240/3325622482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(lambda x: [item['name'] for item in json.loads(x)] if pd.notna(x) else None)
# /tmp/ipykernel_20240/3325622482.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['keywords'] = df['keywords'].apply(lambda x: [item['name'] for item in json.loads(x)] if pd.notna(x) else None)
# /tmp/ipykernel_20240/3325622482.py:5: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4542      9367                               El Mariachi
# 4543     72766                                 Newlyweds
# 4544    231617                 Signed, Sealed, Delivered
# 4545    126186                          Shanghai Calling
# 4546     25975                         My Date with Drew
#
#                                                overview  \
# 0     [In the 22nd century, a paraplegic Marine is d...
# 1     [Captain Barbossa, long believed to be dead, h...
# 2     [A cryptic message from Bond’s past sends him ...
# ...

# %% [markdown]
# We are going to create one column, but first we need to transform everything to strings, except for the crew, that needs a format change

# %%
df['genres'] = df['genres'].apply(lambda x: [str(i) for i in x])

df['keywords'] = df['keywords'].apply(lambda x: [str(j) for j in x])

df['cast'] = df['cast'].apply(lambda x: [str(k) for k in x])

df['crew'] = df['crew'].apply(lambda x: x.split())

df["overview"] = df["overview"].apply(lambda x: [str(x)])
# Out:
# /tmp/ipykernel_20240/3014618041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(lambda x: [str(i) for i in x])
# /tmp/ipykernel_20240/3014618041.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['keywords'] = df['keywords'].apply(lambda x: [str(j) for j in x])
# /tmp/ipykernel_20240/3014618041.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4542      9367                               El Mariachi
# 4543     72766                                 Newlyweds
# 4544    231617                 Signed, Sealed, Delivered
# 4545    126186                          Shanghai Calling
# 4546     25975                         My Date with Drew
#
#                                                overview  \
# 0     [['In the 22nd century, a paraplegic Marine is...
# 1     [['Captain Barbossa, long believed to be dead,...
# 2     [['A cryptic message from Bond’s past sends hi...
# ...

# %% [markdown]
# New column:

# %%
df['tags'] = df['overview']+ df['genres'] + df['cast'] + df['crew'] + df['keywords']
df.drop(['genres', 'keywords', 'cast', 'crew', 'overview'], axis=1 ,inplace = True)

# %% [markdown]
# Change commas for empty spaces:

# %%
df['tags'] = df['tags'].apply(lambda x: ",".join(x).replace(",", " "))

# %%
df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4542      9367                               El Mariachi
# 4543     72766                                 Newlyweds
# 4544    231617                 Signed, Sealed, Delivered
# 4545    126186                          Shanghai Calling
# 4546     25975                         My Date with Drew
#
#                                                    tags
# 0     ['In the 22nd century  a paraplegic Marine is ...
# 1     ['Captain Barbossa  long believed to be dead  ...
# 2     ['A cryptic message from Bond’s past sends him...
# ...

# %%
df['tags'][0]
# Out:
# "['In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization.'] Action Adventure Fantasy Science Fiction Sam Worthington Zoe Saldana Sigourney Weaver James Cameron culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d"

# %% [markdown]
# Let's vectorise the text:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectoriser = TfidfVectorizer()
vec_matrix = vectoriser.fit_transform(df['tags'])

# %% [markdown]
# THE MODEL (with cosine metric)

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors = 5, algorithm = "brute", metric = "cosine")
model.fit(vec_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def recommendation(Movie):
    movie_index = df[df["title"] == Movie].index[0]
    distances, indices = model.kneighbors(vec_matrix[movie_index])
    similar_movies = [(df["title"][i], distances[0][j]) for j, i in enumerate(indices[0])]
    return similar_movies[1:]

mymovie = 'Avatar'
print("Film recommendations '{}'".format(mymovie))
for movie, distance in recommendation(mymovie):
    print("- Film: {}, Distance: {}".format(movie, distance))
# Out:
# Film recommendations 'Avatar'
# - Film: Aliens, Distance: 0.6991891574267721
# - Film: Alien³, Distance: 0.730638365577934
# - Film: Moonraker, Distance: 0.746869887530403
# - Film: Mission to Mars, Distance: 0.7495342395921725

# %%
from pickle import dump

dump(model, open("/workspaces/KNNproject/data/processed/model.sav", "wb"))
